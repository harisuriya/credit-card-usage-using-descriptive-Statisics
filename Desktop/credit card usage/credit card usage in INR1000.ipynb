# %%
import pandas as mypd
mydata = mypd.read_csv("/Users/harisuriya/Desktop/mlworkshop/Data/CC_Expenses_Exercise.csv")

# %%
mydata
# Out:
#     SL No.  Sex  Shopping  Banking  Credit_Card_usage
# 0        1    1         1        1                140
# 1        2    2         2        2                 20
# 2        3    2         1        2                 30
# 3        4    2         1        2                 30
# 4        5    1         1        1                130
# 5        6    2         1        2                 60
# 6        7    2         2        2                 20
# 7        8    2         2        2                 60
# 8        9    2         1        2                 60
# 9       10    1         1        2                150
# 10      11    2         2        2                 30
# 11      12    2         2        2                 40
# 12      13    1         2        1                 90
# 13      14    1         2        2                 80
# 14      15    1         1        2                 50
# 15      16    2         2        2                 30
# ...

# %%
import matplotlib.pyplot as myplot

# %%
cc = mydata.Credit_Card_usage

# %%
cc
# Out:
# 0     140
# 1      20
# 2      30
# 3      30
# 4     130
# 5      60
# 6      20
# 7      60
# 8      60
# 9     150
# 10     30
# 11     40
# 12     90
# 13     80
# 14     50
# 15     30
# 16     90
# 17     40
# 18    140
# 19     60
# 20     90
# 21     50
# 22     20
# 23    150
# 24     60
# 25    130
# 26     40
# 27     20
# 28     40
# 29     30
# Name: Credit_Card_usage, dtype: int64

# %%
mydata
# Out:
#     SL No.  Sex  Shopping  Banking  Credit_Card_usage
# 0        1    1         1        1                140
# 1        2    2         2        2                 20
# 2        3    2         1        2                 30
# 3        4    2         1        2                 30
# 4        5    1         1        1                130
# 5        6    2         1        2                 60
# 6        7    2         2        2                 20
# 7        8    2         2        2                 60
# 8        9    2         1        2                 60
# 9       10    1         1        2                150
# 10      11    2         2        2                 30
# 11      12    2         2        2                 40
# 12      13    1         2        1                 90
# 13      14    1         2        2                 80
# 14      15    1         1        2                 50
# 15      16    2         2        2                 30
# ...

# %%
cc = mydata["Credit_Card_usage"]

# %%
cc
# Out:
# 0     140
# 1      20
# 2      30
# 3      30
# 4     130
# 5      60
# 6      20
# 7      60
# 8      60
# 9     150
# 10     30
# 11     40
# 12     90
# 13     80
# 14     50
# 15     30
# 16     90
# 17     40
# 18    140
# 19     60
# 20     90
# 21     50
# 22     20
# 23    150
# 24     60
# 25    130
# 26     40
# 27     20
# 28     40
# 29     30
# Name: Credit_Card_usage, dtype: int64

# %%
cc.describe()
# Out:
# count     30.000000
# mean      66.000000
# std       42.959484
# min       20.000000
# 25%       30.000000
# 50%       55.000000
# 75%       90.000000
# max      150.000000
# Name: Credit_Card_usage, dtype: float64

# %%
gender = mydata.Sex
shopping = mydata.Shopping
banking = mydata.Banking

# %%
mydata.groupby(gender).mean()
# Out:
#      SL No.  Shopping   Banking  Credit_Card_usage
# Sex
# 1      17.6  1.266667  1.466667          93.333333
# 2      13.4  1.600000  1.933333          38.666667

# %%
mydata.boxplot(column="Credit_Card_usage",by = ["Sex","Banking" ])

# %%
myplot.show()

# %%
mydata.groupby([gender,shopping,banking]).describe()
# Out:
#                      Credit_Card_usage                                      \
#                                  count        mean        std   min    25%
# Sex Shopping Banking
# 1   1        1                     6.0  130.000000  20.976177  90.0  130.0
#              2                     5.0   62.000000  49.699095  30.0   40.0
#     2        1                     2.0   70.000000  28.284271  50.0   60.0
#              2                     2.0   85.000000   7.071068  80.0   82.5
# 2   1        1                     1.0   40.000000        NaN  40.0   40.0
#              2                     5.0   48.000000  16.431677  30.0   30.0
#     2        2                     9.0   33.333333  16.583124  20.0   20.0
#
#                                           SL No.                              \
#                         50%    75%    max  count       mean        std   min
# Sex Shopping Banking
# 1   1        1        135.0  140.0  150.0    6.0  15.333333  10.171857   1.0
# ...
